# %%
#import pandas 
import pandas as pd

# %%
#Read the data 
df = pd.read_csv("credit-card-fraud-detection.csv")

# %%
#Extract Frist Five Data
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      50000    1          2         1   57     -1      0     -1      0
# 1      50000    1          1         2   37      0      0      0      0
# 2     500000    1          1         2   29      0      0      0      0
# 3     100000    2          2         2   23      0     -1     -1      0
# 4     140000    2          3         1   28      0      0      2      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      20940      19146      19131      2000     36681     10000
# 1      0  ...      19394      19619      20024      2500      1815       657
# 2      0  ...     542653     483003     473944     55000     40000     38000
# 3      0  ...        221       -159        567       380       601         0
# 4      0  ...      12211      11793       3719      3329         0       432
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
#Data Info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   1001 non-null   int64
#  1   SEX                         1001 non-null   int64
#  2   EDUCATION                   1001 non-null   int64
#  3   MARRIAGE                    1001 non-null   int64
#  4   AGE                         1001 non-null   int64
#  5   PAY_0                       1001 non-null   int64
#  6   PAY_2                       1001 non-null   int64
#  7   PAY_3                       1001 non-null   int64
#  8   PAY_4                       1001 non-null   int64
#  9   PAY_5                       1001 non-null   int64
#  10  PAY_6                       1001 non-null   int64
#  11  BILL_AMT1                   1001 non-null   int64
#  12  BILL_AMT2                   1001 non-null   int64
# ...

# %%
#Display columns 
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
#Display the size 
df.size
# Out:
# 24024

# %%
#Display the shape 
df.shape
# Out:
# (1001, 24)

# %%
#Checking for duplicate
df.duplicated().sum()
# Out:
# 0

# %%
#Checking for null values 
df.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
#Descriptive Stat
df.describe().T
# Out:
#                              count           mean            std       min  \
# LIMIT_BAL                   1001.0  167532.467532  130587.921320   10000.0
# SEX                         1001.0       1.589411       0.492187       1.0
# EDUCATION                   1001.0       1.776224       0.750916       1.0
# MARRIAGE                    1001.0       1.604396       0.532298       0.0
# AGE                         1001.0      34.945055       9.219760      21.0
# PAY_0                       1001.0      -0.004995       1.173446      -2.0
# PAY_2                       1001.0      -0.161838       1.228732      -2.0
# PAY_3                       1001.0      -0.164835       1.262459      -2.0
# PAY_4                       1001.0      -0.283716       1.184662      -2.0
# PAY_5                       1001.0      -0.283716       1.170224      -2.0
# PAY_6                       1001.0      -0.314685       1.203276      -2.0
# ...

# %%
df.skew()
# Out:
# LIMIT_BAL                      1.011019
# SEX                           -0.364047
# EDUCATION                      0.875019
# MARRIAGE                      -0.104653
# AGE                            0.817570
# PAY_0                          1.509158
# PAY_2                          1.208410
# PAY_3                          1.226851
# PAY_4                          1.217037
# PAY_5                          1.053218
# PAY_6                          1.064620
# BILL_AMT1                      2.671027
# BILL_AMT2                      2.777126
# BILL_AMT3                      2.901497
# BILL_AMT4                      3.578203
# BILL_AMT5                      3.107180
# BILL_AMT6                      2.636691
# PAY_AMT1                       7.749893
# PAY_AMT2                      10.752948
# PAY_AMT3                       6.744377
# PAY_AMT4                       7.454775
# PAY_AMT5                       7.034632
# PAY_AMT6                      15.241538
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
#Divide Independent and Dependent Features
X = df.drop(labels=['default payment next month'],axis=1)
y = df['default payment next month']

# %%
X.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      50000    1          2         1   57     -1      0     -1      0
# 1      50000    1          1         2   37      0      0      0      0
# 2     500000    1          1         2   29      0      0      0      0
# 3     100000    2          2         2   23      0     -1     -1      0
# 4     140000    2          3         1   28      0      0      2      0
#
#    PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0      0  ...      35835      20940      19146      19131      2000     36681
# 1      0  ...      57608      19394      19619      20024      2500      1815
# 2      0  ...     445007     542653     483003     473944     55000     40000
# 3      0  ...        601        221       -159        567       380       601
# 4      0  ...      12108      12211      11793       3719      3329         0
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 996     0
# 997     0
# 998     0
# 999     1
# 1000    1
# Name: default payment next month, Length: 1001, dtype: int64

# %%
#Train test split 
from sklearn.model_selection import train_test_split

XX_train , XX_test , yy_train , yy_test = train_test_split(X,y,test_size=30,random_state=42)

# %%
XX_train
# Out:
#      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 346      90000    1          1         2   26      0      0     -1      0
# 139     170000    1          2         2   29     -2     -2     -2     -2
# 622      70000    1          1         1   46      0      0      0      0
# 499     130000    2          1         1   33      0      0      0      0
# 370     180000    1          1         1   46      0      0      0      0
# ..         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 106     330000    2          1         1   31      0      0      2      0
# 270     360000    2          2         2   28     -2     -2     -2     -2
# 860     200000    1          1         2   32      0      0      0      0
# 435      80000    2          1         2   23      0      0      0      0
# 102      80000    2          2         1   36     -1     -1     -1     -1
#
#      PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# ...

# %%
#Scaling the Data 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() #Instance

# %%
X_train = scaler.fit_transform(XX_train)
X_test = scaler.transform(XX_test)

# %%
X_train
# Out:
# array([[-0.59131767, -1.19478031, -1.03128045, ..., -0.35338865,
#          1.03954927, -0.08542514],
#        [ 0.02096648, -1.19478031,  0.29856459, ...,  0.3890262 ,
#          0.61464567,  0.21218605],
#        [-0.7443887 , -1.19478031, -1.03128045, ..., -0.11987341,
#         -0.19917562, -0.1364442 ],
#        ...,
#        [ 0.25057303, -1.19478031, -1.03128045, ..., -0.22502964,
#         -0.14047106, -0.10668308],
#        [-0.66785318,  0.83697395, -1.03128045, ...,  2.62132775,
#         -0.21091653, -0.14069579],
#        [-0.66785318,  0.83697395,  0.29856459, ..., -0.26786555,
#         -0.24907449, -0.16896885]])

# %%
X_test
# Out:
# array([[ 4.03644064e-01,  8.36973951e-01,  2.98564593e-01,
#          7.67627907e-01, -8.66648852e-01, -8.43978066e-01,
#         -6.78194412e-01, -6.61263828e-01, -6.08482998e-01,
#         -6.15547567e-01, -5.68823358e-01, -6.55253118e-01,
#         -4.79808877e-01, -6.39825899e-01, -5.76434583e-01,
#         -6.20878892e-01, -5.57479695e-01,  6.41452032e-01,
#         -2.95315179e-01, -2.25790693e-01, -3.53388649e-01,
#         -1.46869857e-01,  6.31338543e+00],
#        [ 1.47514131e+00,  8.36973951e-01, -1.03128045e+00,
#          7.67627907e-01, -6.49371280e-01,  3.49111920e-03,
#          1.30806539e-01, -6.61263828e-01, -6.08482998e-01,
#         -6.15547567e-01, -5.68823358e-01, -4.60594353e-01,
#         -5.50154069e-01, -6.31618496e-01, -5.88699219e-01,
#         -6.10644045e-01, -5.47697444e-01, -3.58530217e-01,
#         -2.59229753e-01, -3.03715383e-01, -3.05346979e-01,
#         -1.10649145e-01, -2.12972789e-01],
# ...

# %%
#Make data frame of scaled data
scaled_train_data = pd.DataFrame(X_train,columns=XX_train.columns,index=XX_train.index)
scaled_test_data = pd.DataFrame(X_test,columns=XX_test.columns,index=XX_test.index)

# %%
scaled_train_data.head()
# Out:
#      LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE     PAY_0     PAY_2  \
# 346  -0.591318 -1.194780  -1.031280  0.767628 -0.975288  0.003491  0.130807
# 139   0.020966 -1.194780   0.298565  0.767628 -0.649371 -1.691447 -1.487195
# 622  -0.744389 -1.194780  -1.031280 -1.128979  1.197488  0.003491  0.130807
# 499  -0.285176  0.836974  -1.031280 -1.128979 -0.214816  0.003491  0.130807
# 370   0.097502 -1.194780  -1.031280 -1.128979  1.197488  0.003491  0.130807
#
#         PAY_3     PAY_4     PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 346 -0.661264  0.241642  0.240751  ...  -0.618165  -0.574818  -0.620879
# 139 -1.455926 -1.458608 -1.471847  ...  -0.502312  -0.455286  -0.462714
# 622  0.133399  0.241642  0.240751  ...   0.098021   0.163982   0.171498
# 499  0.133399  0.241642  0.240751  ...  -0.319708  -0.272814  -0.267507
# 370  0.133399  0.241642  0.240751  ...   1.872703   0.972691  -0.175853
#
#      BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %%
scaled_test_data.head()
# Out:
#      LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE     PAY_0     PAY_2  \
# 521   0.403644  0.836974   0.298565  0.767628 -0.866649 -0.843978 -0.678194
# 941   1.475141  0.836974  -1.031280  0.767628 -0.649371  0.003491  0.130807
# 741   0.020966 -1.194780   1.628410  0.767628  0.328378  0.003491  0.130807
# 980  -0.897460  0.836974  -1.031280  0.767628 -1.301204 -1.691447 -1.487195
# 411  -0.897460  0.836974   1.628410 -1.128979  0.002461 -0.843978 -0.678194
#
#         PAY_3     PAY_4     PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 521 -0.661264 -0.608483 -0.615548  ...  -0.639826  -0.576435  -0.620879
# 941 -0.661264 -0.608483 -0.615548  ...  -0.631618  -0.588699  -0.610644
# 741  0.133399  0.241642  0.240751  ...  -0.297257  -0.224586  -0.146384
# 980 -1.455926 -1.458608 -1.471847  ...   0.072953  -0.305293  -0.323387
# 411 -0.661264 -1.458608 -1.471847  ...  -0.646050  -0.603589  -0.620879
#
#      BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %%
## Model Training 
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# %%
#Creating Instance 

nb = GaussianNB()
rf = RandomForestClassifier()

# %%
#Now fit the data 
nb.fit(scaled_train_data,yy_train)
rf.fit(scaled_train_data,yy_train)
# Out:
# RandomForestClassifier()

# %%
#Import metrics 
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

#Prediction For Naive Bayes 
y_pred_nb = nb.predict(scaled_test_data)

#Performance For Naive Bayes
print(f"Confusion Matrix Naive bayes :  {confusion_matrix(yy_test,y_pred_nb)}")
print(f"Classification Report  Naive bayes:{classification_report(yy_test,y_pred_nb)}")
print(f"Accuracy Score Naive bayes :  {accuracy_score(yy_test,y_pred_nb)}")
# Out:
# Confusion Matrix Naive bayes :  [[21  4]
#  [ 2  3]]
# Classification Report  Naive bayes:              precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87        25
#            1       0.43      0.60      0.50         5
#
#     accuracy                           0.80        30
#    macro avg       0.67      0.72      0.69        30
# weighted avg       0.83      0.80      0.81        30
#
# Accuracy Score Naive bayes :  0.8

# %%
#Prediction For Random Forest
y_pred_nb = rf.predict(scaled_test_data)

#Performance For Random Forest 
print(f"Confusion Matrix Random Forest:  {confusion_matrix(yy_test,y_pred_nb)}")
print(f"Classification Report  Random Forest:  {classification_report(yy_test,y_pred_nb)}")
print(f"Accuracy Score Random Forest :  {accuracy_score(yy_test,y_pred_nb)}")
# Out:
# Confusion Matrix Random Forest:  [[24  1]
#  [ 4  1]]
# Classification Report  Random Forest:                precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91        25
#            1       0.50      0.20      0.29         5
#
#     accuracy                           0.83        30
#    macro avg       0.68      0.58      0.60        30
# weighted avg       0.80      0.83      0.80        30
#
# Accuracy Score Random Forest :  0.8333333333333334

# %%
#Hyperparameter Tunning 
from sklearn.model_selection import GridSearchCV
param_grid = {'var_smoothing':[0.1,0.01,0.5,0.005,0.001,1e-6,1e-8,1e-10,1e-11]}
grid = GridSearchCV(estimator=nb,param_grid=param_grid,cv=5,verbose=3)

# %%
grid.fit(scaled_train_data,yy_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END .................var_smoothing=0.1;, score=0.708 total time=   0.0s
# [CV 2/5] END .................var_smoothing=0.1;, score=0.680 total time=   0.0s
# [CV 3/5] END .................var_smoothing=0.1;, score=0.768 total time=   0.0s
# [CV 4/5] END .................var_smoothing=0.1;, score=0.737 total time=   0.0s
# [CV 5/5] END .................var_smoothing=0.1;, score=0.737 total time=   0.0s
# [CV 1/5] END ................var_smoothing=0.01;, score=0.687 total time=   0.0s
# [CV 2/5] END ................var_smoothing=0.01;, score=0.521 total time=   0.0s
# [CV 3/5] END ................var_smoothing=0.01;, score=0.778 total time=   0.0s
# [CV 4/5] END ................var_smoothing=0.01;, score=0.711 total time=   0.0s
# [CV 5/5] END ................var_smoothing=0.01;, score=0.737 total time=   0.0s
# [CV 1/5] END .................var_smoothing=0.5;, score=0.774 total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'var_smoothing': 0.5}

# %%
grid.best_estimator_
# Out:
# GaussianNB(var_smoothing=0.5)

# %%
model_nb = GaussianNB(var_smoothing=0.5)
model_nb.fit(scaled_train_data,yy_train)
y_pred_nb = model_nb.predict(scaled_test_data)

#Performance For Naive Bayes
print(f"Confusion Matrix Naive bayes :  {confusion_matrix(yy_test,y_pred_nb)}")
print(f"Classification Report  Naive bayes:{classification_report(yy_test,y_pred_nb)}")
print(f"Accuracy Score Naive bayes :  {accuracy_score(yy_test,y_pred_nb)}")
# Out:
# Confusion Matrix Naive bayes :  [[23  2]
#  [ 4  1]]
# Classification Report  Naive bayes:              precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88        25
#            1       0.33      0.20      0.25         5
#
#     accuracy                           0.80        30
#    macro avg       0.59      0.56      0.57        30
# weighted avg       0.77      0.80      0.78        30
#
# Accuracy Score Naive bayes :  0.8
